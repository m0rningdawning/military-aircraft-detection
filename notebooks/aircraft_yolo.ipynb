# %%
# !nvidia-smi
# Out:
# Tue Oct 29 21:44:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.7/877.7 kB 22.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Found existing installation: wandb 0.18.5
# Uninstalling wandb-0.18.5:
#   Successfully uninstalled wandb-0.18.5
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/235.7 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                32.3/235.7 GB
# CPU                 Intel Xeon 2.20GHz
# CPU count           2
# GPU                 Tesla T4, 15102MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4>=1.23.0
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.4.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.5.0+cu121>=1.8.0
# torchvision         ✅ 0.20.0+cu121>=0.9.0
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d rookieengg/military-aircraft-detection-dataset-yolo-format
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rookieengg/military-aircraft-detection-dataset-yolo-format
# License(s): MIT
# ...
# 100% 8.35G/8.35G [02:20<00:00, 76.2MB/s]
# 100% 8.35G/8.35G [02:20<00:00, 63.7MB/s]

# %%
# !unzip military-aircraft-detection-dataset-yolo-format.zip -d /content/datasets
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/datasets/military/labels/aircraft_train/94a03f5cddcf37a7fa9548f53d4cb67c.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94a38dc0f8440c8249d7ec31d3a8a99a.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94a4ea41178f4c62772aac0c8e77d69a.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94a6eb6524a79738c103d633e05c4f02.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94aa78cb4d43dbc27c24d0004d808c85.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94b99fb54920a8a04872dad58daf2f9c.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94c4a67281804188bff887b648ec7856.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94cf73e4a7f609fb67c2bd364cabd2d0.txt
#   inflating: /content/datasets/military/labels/aircraft_train/94d7ad295de2c3f8cad614b753c4e4f3.txt
# ...

# %%
cat aircraft_names.yaml
# Out:
# path: military  # dataset root dir
# train: images/aircraft_train  # train images (relative to 'path') 118287 images
# val: images/aircraft_val  # val images (relative to 'path') 5000 images
# test:
#
# names:
#   0: A10
#   1: A400M
#   2: AG600
#   3: AV8B
#   4: B1
#   5: B2
#   6: B52
#   7: Be200
#   8: C130
#   9: C17
#   10: C2
#   11: C5
#   12: E2
#   13: E7
#   14: EF2000
#   15: F117
#   16: F14
#   17: F15
#   18: F16
#   19: F18
#   20: F22
#   21: F35
#   22: F4
#   23: J20
#   24: JAS39
#   25: MQ9
#   26: Mig31
#   27: Mirage2000
#   28: P3
#   29: RQ4
#   30: Rafale
#   31: SR71
#   32: Su34
#   33: Su57
#   34: Tornado
#   35: Tu160
#   36: Tu95
#   37: U2
#   38: US2
#   39: V22
#   40: Vulcan
#   41: XB70
#   42: YF23

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=aircraft_names.yaml epochs=30 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 337MB/s]
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
yolo train resume model=path/to/last.pt
